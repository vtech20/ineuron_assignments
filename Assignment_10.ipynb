# %% [markdown]
# **1.How do you distinguish between shutil.copy() and shutil.copytree()?**

# %% [markdown]
# * shutil.copy() - Copies the single file
# * shutil.copytree() - Copies the entire folder and its every content

# %%
import shutil, os

# %%
shutil.copy('C:\\Users\\vr19\\Test.csv','C:\\Users\\vr19\\Desktop')
# Out:
# 'C:\\Users\\vr19\\Desktop\\Test.csv'

# %%
shutil.copytree('C:\\Users\\vr19\\Documents\\Fax\\Inbox\\','C:\\Users\\vr19\\temp_shutil1')
# Out:
# 'C:\\Users\\vr19\\temp_shutil1'

# %% [markdown]
# **2. What function is used to rename files??**

# %% [markdown]
# os.rename() method used to rename files or folders

# %% [markdown]
# **3. What is the difference between the delete functions in the send2trash and shutil modules?**

# %% [markdown]
# * send2trash  - Send files and folders to trash
# * shutil delete functions - permanently delete files and folders

# %% [markdown]
# **4.ZipFile objects have a close() method just like File objects’ close() method. What ZipFile method is
# equivalent to File objects’ open() method?**

# %% [markdown]
# The ZipFile() function is similar to the open() method in that it takes two arguments: the filename and the mode to open the ZIP file in (read, write, or append)

# %% [markdown]
# **5. Create a programme that searches a folder tree for files with a certain file extension (such as .pdf
# or .jpg). Copy these files from whatever location they are in to a new folder.**

# %%
import shutil, os

def find_and_copy(source_folder,file_extension,destination_folder):
    try:
        source_folder = os.path.abspath(source_folder)
        destination_folder = os.path.abspath(destination_folder)
        print("Searching files in folder {}, with the extensions {}".format(source_folder,",".join(file_extension)))
        count = 1
        for foldername, subfolders, filenames in os.walk(source_folder):
            for filename in filenames:
                name, extension = os.path.splitext(filename)
                if extension in extensions:
                    file_absolute_path = foldername + os.path.sep + filename
                    print("File Path is....")
                    print(file_absolute_path)
                    print("started copying {} to the folder {}".format(file_absolute_path,destination_folder))
                    shutil.copy(file_absolute_path, destination_folder)
                    count+=1
        print("Successfully copied {} all files and folders".format(count))
    except Exception as e:
        print("Exception occured while coping all files and folders",str(e))

# %%
source_path = input('Enter the source path :')
destination_path = input('Enter the destination path :')
no_of_ext = int(input('Enter the number of extensions to search :'))
extensions = []
for i in range(1,no_of_ext+1):
    ex = input('Enter the {} extension to search :'.format(i))
    extensions.append(ex)

find_and_copy(source_path,extensions,destination_path)
# Out:
# Enter the source path :C:\\Users\\vr19
# Enter the destination path :C:\\Users\\vr19\\Desktop\\test_files
# Enter the number of extensions to search :2
# Enter the 1 extension to search :.jpg
# Enter the 2 extension to search :.pdf
# Searching files in folder C:\Users\vr19, with the extensions .jpg,.pdf
# File Path is....
# C:\Users\vr19\AppData\Local\conda\conda\pkgs\scikit-learn-0.24.2-py36h35b34c0_0\Lib\site-packages\sklearn\datasets\images\china.jpg
# started copying C:\Users\vr19\AppData\Local\conda\conda\pkgs\scikit-learn-0.24.2-py36h35b34c0_0\Lib\site-packages\sklearn\datasets\images\china.jpg to the folder C:\Users\vr19\Desktop\test_files
# File Path is....
# C:\Users\vr19\AppData\Local\conda\conda\pkgs\scikit-learn-0.24.2-py36h35b34c0_0\Lib\site-packages\sklearn\datasets\images\flower.jpg
# ...
